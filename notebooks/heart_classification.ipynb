# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw_data/heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.shape
# Out:
# (1025, 14)

# %%
df['target'].value_counts(normalize=False)
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
df['target'].value_counts(normalize=True) * 100
# Out:
# target
# 1    51.317073
# 0    48.682927
# Name: proportion, dtype: float64

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df[df.duplicated(keep=False)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df[df.duplicated(keep=False)].sort_values(by=list(df.columns))
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 60    29    1   1       130   204    0        0      202      0      0.0
# 64    29    1   1       130   204    0        0      202      0      0.0
# 118   29    1   1       130   204    0        0      202      0      0.0
# 668   29    1   1       130   204    0        0      202      0      0.0
# 12    34    0   1       118   210    0        1      192      0      0.7
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 535   76    0   2       140   197    0        2      116      0      1.1
# 965   76    0   2       140   197    0        2      116      0      1.1
# 160   77    1   0       125   304    0        0      162      1      0.0
# 162   77    1   0       125   304    0        0      162      1      0.0
# 387   77    1   0       125   304    0        0      162      1      0.0
#
#      slope  ca  thal  target
# 60       2   0     2       1
# 64       2   0     2       1
# ...

# %%
df_copy = df.copy()

# %%
df_copy = df_copy.drop_duplicates()

# %%
df_copy.shape
# Out:
# (302, 14)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.countplot(data=df_copy, x=df_copy['target'])
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
num_col = df_copy.select_dtypes(include=['int64', 'float64']).columns.drop('target')

# %%
for col in num_col:
    plt.figure(figsize=(6,4))
    sns.histplot(data=df_copy, x=col, hue='target', kde=True, element='step')
    plt.show()

# %%
for col in num_col:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='target', y=col, data=df_copy)
    plt.title(f"{col} vs Target")
    plt.show()

# %%
categorical_cols = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']

for col in categorical_cols:
    sns.countplot(x=col, hue='target', data=df_copy)
    plt.title(f"{col} counts by Target")
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
sns.heatmap(df_copy.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
